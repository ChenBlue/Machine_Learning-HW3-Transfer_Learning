# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os
import tensorflow as tf
import time

# to make this notebook's output stable across runs
def reset_graph(seed=42): 
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

reset_graph()

# %%
# load data: digits 5 to 9, but still label with 0 to 4, 
# because TensorFlow expects label's integers from 0 to n_classes-1.
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/")

X_train2_full = mnist.train.images[mnist.train.labels >= 5]
y_train2_full = mnist.train.labels[mnist.train.labels >= 5] - 5
X_valid2_full = mnist.validation.images[mnist.validation.labels >= 5]
y_valid2_full = mnist.validation.labels[mnist.validation.labels >= 5] - 5
X_test2 = mnist.test.images[mnist.test.labels >= 5]
y_test2 = mnist.test.labels[mnist.test.labels >= 5] - 5
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# we want to keep only 100 instances per class in the training set 
# and let's keep only 30 instances per class in the validation set
# tesing set is already loaded above
def sample_n_instances_per_class(X, y, n=100):
    Xs, ys = [], []
    for label in np.unique(y):
        idx = (y == label)
        Xc = X[idx][:n]
        yc = y[idx][:n]
        Xs.append(Xc)
        ys.append(yc)
    return np.concatenate(Xs), np.concatenate(ys)

X_train2, y_train2 = sample_n_instances_per_class(X_train2_full, y_train2_full, n=100)
X_valid2, y_valid2 = sample_n_instances_per_class(X_valid2_full, y_valid2_full, n=30)

# %%
learning_rate = 0.001
batch_size = 16
train_size = X_train2.shape[0]

#saver = tf.train.Saver()
t0 = time.time()
with tf.Session() as sess:
    new_saver = tf.train.import_meta_graph('/Team48_HW2.ckpt.meta', clear_devices=True)
    new_saver.restore(sess, '/Team48_HW2.ckpt')
    xs = tf.get_default_graph().get_tensor_by_name("xs:0")
    ys = tf.get_default_graph().get_tensor_by_name("ys:0")
    y = tf.get_default_graph().get_tensor_by_name("y:0")
    #logits = y.op.inputs[0]
    accuracy = tf.get_default_graph().get_tensor_by_name("accuracy:0")
    output_layer_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope="logits")
    loss = tf.get_default_graph().get_tensor_by_name("loss:0")
    optimizer = tf.train.AdamOptimizer(learning_rate, name="optimizer")
    training_op = optimizer.minimize(loss, var_list=output_layer_vars, name="training_op")
    
    tf.global_variables_initializer().run() 
    
    best_loss = 99999
    stand_epoch = 0
    
    for i in range(1000):
        #sess.run(training_op, feed_dict={xs: X_train2, ys: y_train2})
        stand_epoch = stand_epoch + 1
        for j in range(int(train_size/batch_size)):
            # get batch data each time
            batch_x = X_train2[j*batch_size:(j+1)*batch_size,:]
            batch_y = y_train2[j*batch_size:(j+1)*batch_size]
            # training
            sess.run(training_op, feed_dict={xs: batch_x, ys: batch_y})
        
        val_loss = sess.run(loss, feed_dict={xs: X_valid2, ys: y_valid2})
        if best_loss > val_loss:
            stand_epoch = 0
            best_loss = val_loss
            
        
        accu = sess.run(accuracy, feed_dict={xs: X_test2, ys: y_test2})
        print(i,"Validation loss:", val_loss, " ; Best loss:", best_loss, " ; Accuracy:", accu)
        
        if stand_epoch >= 20: # Early stop
            print("Early stop in epoch", i)
            break
    save_path = new_saver.save(sess, "/Team48_HW3_1.ckpt") # save variables to checkpoint

sess.close()
t1 = time.time()
print(t1-t0)
print("Training Finish!!!")
# Out:
# INFO:tensorflow:Restoring parameters from /Team48_HW2.ckpt
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#
# ~\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# InternalError: Blas GEMM launch failed : a.shape=(16, 784), b.shape=(784, 128), m=16, n=128, k=784
# 	 [[Node: l1/MatMul = MatMul[T=DT_FLOAT, transpose_a=false, transpose_b=false, _device="/job:localhost/replica:0/task:0/gpu:0"](_recv_xs_0/_77, l1/kernel/read)]]
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-9-ba2dc6ae2c06> in <module>()
#      31             batch_y = y_train2[j*batch_size:(j+1)*batch_size]
#      32             # training
# ---> 33             sess.run(training_op, feed_dict={xs: batch_x, ys: batch_y})
#      34
#      35         val_loss = sess.run(loss, feed_dict={xs: X_valid2, ys: y_valid2})
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1050         except KeyError:
#    1051           pass
# -> 1052       raise type(e)(node_def, op, message)
#    1053
#    1054   def _extend_graph(self):
#
# InternalError: Blas GEMM launch failed : a.shape=(16, 784), b.shape=(784, 128), m=16, n=128, k=784
# 	 [[Node: l1/MatMul = MatMul[T=DT_FLOAT, transpose_a=false, transpose_b=false, _device="/job:localhost/replica:0/task:0/gpu:0"](_recv_xs_0/_77, l1/kernel/read)]]
#
# Caused by op 'l1/MatMul', defined at:
#   File "C:\Users\alice\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\alice\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\alice\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\alice\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Users\alice\Anaconda3\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Users\alice\Anaconda3\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Users\alice\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\alice\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-9-ba2dc6ae2c06>", line 8, in <module>
#     new_saver = tf.train.import_meta_graph('/Team48_HW2.ckpt.meta', clear_devices=True)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1595, in import_meta_graph
#     **kwargs)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\tensorflow\python\framework\meta_graph.py", line 499, in import_scoped_meta_graph
#     producer_op_list=producer_op_list)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\tensorflow\python\framework\importer.py", line 308, in import_graph_def
#     op_def=op_def)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 2336, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "C:\Users\alice\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1228, in __init__
#     self._traceback = _extract_stack()
#
# InternalError (see above for traceback): Blas GEMM launch failed : a.shape=(16, 784), b.shape=(784, 128), m=16, n=128, k=784
# 	 [[Node: l1/MatMul = MatMul[T=DT_FLOAT, transpose_a=false, transpose_b=false, _device="/job:localhost/replica:0/task:0/gpu:0"](_recv_xs_0/_77, l1/kernel/read)]]

# %%
with tf.Session() as sess:
    new_saver = tf.train.import_meta_graph('/Team48_HW2.ckpt.meta', clear_devices=True)
    new_saver.restore(sess, '/Team48_HW2.ckpt')
    xs = tf.get_default_graph().get_tensor_by_name("xs:0")
    ys = tf.get_default_graph().get_tensor_by_name("ys:0")
    y = tf.get_default_graph().get_tensor_by_name("y:0")
    #logits = y.op.inputs[0]
    accuracy = tf.get_default_graph().get_tensor_by_name("accuracy:0")
    output_layer_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope="logits")
    loss = tf.get_default_graph().get_tensor_by_name("loss:0")
    optimizer = tf.train.AdamOptimizer(learning_rate, name="optimizer")
    training_op = optimizer.minimize(loss, var_list=output_layer_vars, name="training_op")
    
    tf.global_variables_initializer().run() 
    
    best_loss = 99999
    stand_epoch = 0
    
    for i in range(1000):
        #sess.run(training_op, feed_dict={xs: X_train2, ys: y_train2})
        stand_epoch = stand_epoch + 1
        for j in range(int(train_size/batch_size)):
            # get batch data each time
            batch_x = X_train2[j*batch_size:(j+1)*batch_size,:]
            batch_y = y_train2[j*batch_size:(j+1)*batch_size]
            # training
            sess.run(training_op, feed_dict={xs: batch_x, ys: batch_y})
        
        val_loss = sess.run(loss, feed_dict={xs: X_valid2, ys: y_valid2})
        if best_loss > val_loss:
            stand_epoch = 0
            best_loss = val_loss
            
        
        accu = sess.run(accuracy, feed_dict={xs: X_test2, ys: y_test2})
        print(i,"Validation loss:", val_loss, " ; Best loss:", best_loss, " ; Accuracy:", accu)
        
        if stand_epoch >= 20: # Early stop
            print("Early stop in epoch", i)
            break
    save_path = new_saver.save(sess, "/Team48_HW3_1.ckpt") # save variables to checkpoint

print("Training Finish!!!")
sess.close()
# Out:
# INFO:tensorflow:Restoring parameters from /Team48_HW2.ckpt
# 0 Validation loss: 230.341  ; Best loss: 230.341  ; Accuracy: 0.341082
# 1 Validation loss: 219.703  ; Best loss: 219.703  ; Accuracy: 0.476445
# 2 Validation loss: 211.143  ; Best loss: 211.143  ; Accuracy: 0.545361
# 3 Validation loss: 205.506  ; Best loss: 205.506  ; Accuracy: 0.582802
# 4 Validation loss: 200.037  ; Best loss: 200.037  ; Accuracy: 0.612425
# 5 Validation loss: 192.39  ; Best loss: 192.39  ; Accuracy: 0.668175
# 6 Validation loss: 186.899  ; Best loss: 186.899  ; Accuracy: 0.697799
# 7 Validation loss: 184.099  ; Best loss: 184.099  ; Accuracy: 0.71117
# 8 Validation loss: 181.691  ; Best loss: 181.691  ; Accuracy: 0.724748
# 9 Validation loss: 179.81  ; Best loss: 179.81  ; Accuracy: 0.731948
# 10 Validation loss: 178.311  ; Best loss: 178.311  ; Accuracy: 0.739765
# 11 Validation loss: 177.075  ; Best loss: 177.075  ; Accuracy: 0.747583
# 12 Validation loss: 176.033  ; Best loss: 176.033  ; Accuracy: 0.751903
# 13 Validation loss: 175.139  ; Best loss: 175.139  ; Accuracy: 0.757046
# 14 Validation loss: 174.36  ; Best loss: 174.36  ; Accuracy: 0.760543
# 15 Validation loss: 173.674  ; Best loss: 173.674  ; Accuracy: 0.76404
# 16 Validation loss: 173.065  ; Best loss: 173.065  ; Accuracy: 0.767743
# 17 Validation loss: 172.521  ; Best loss: 172.521  ; Accuracy: 0.769595
# 18 Validation loss: 172.032  ; Best loss: 172.032  ; Accuracy: 0.772886
# 19 Validation loss: 171.592  ; Best loss: 171.592  ; Accuracy: 0.775355
# 20 Validation loss: 171.192  ; Best loss: 171.192  ; Accuracy: 0.777206
# 21 Validation loss: 170.829  ; Best loss: 170.829  ; Accuracy: 0.779263
# 22 Validation loss: 170.495  ; Best loss: 170.495  ; Accuracy: 0.781938
# 23 Validation loss: 170.187  ; Best loss: 170.187  ; Accuracy: 0.782555
# 24 Validation loss: 169.9  ; Best loss: 169.9  ; Accuracy: 0.782966
# 25 Validation loss: 169.631  ; Best loss: 169.631  ; Accuracy: 0.784612
# 26 Validation loss: 169.378  ; Best loss: 169.378  ; Accuracy: 0.786258
# 27 Validation loss: 169.139  ; Best loss: 169.139  ; Accuracy: 0.788521
# 28 Validation loss: 168.914  ; Best loss: 168.914  ; Accuracy: 0.789755
# 29 Validation loss: 168.701  ; Best loss: 168.701  ; Accuracy: 0.790578
# 30 Validation loss: 168.5  ; Best loss: 168.5  ; Accuracy: 0.790989
# 31 Validation loss: 168.31  ; Best loss: 168.31  ; Accuracy: 0.792429
# 32 Validation loss: 168.13  ; Best loss: 168.13  ; Accuracy: 0.792841
# 33 Validation loss: 167.961  ; Best loss: 167.961  ; Accuracy: 0.794075
# 34 Validation loss: 167.802  ; Best loss: 167.802  ; Accuracy: 0.794281
# 35 Validation loss: 167.652  ; Best loss: 167.652  ; Accuracy: 0.795515
# 36 Validation loss: 167.512  ; Best loss: 167.512  ; Accuracy: 0.796132
# 37 Validation loss: 167.38  ; Best loss: 167.38  ; Accuracy: 0.795721
# 38 Validation loss: 167.257  ; Best loss: 167.257  ; Accuracy: 0.795309
# 39 Validation loss: 167.142  ; Best loss: 167.142  ; Accuracy: 0.796132
# 40 Validation loss: 167.034  ; Best loss: 167.034  ; Accuracy: 0.796544
# 41 Validation loss: 166.934  ; Best loss: 166.934  ; Accuracy: 0.797161
# 42 Validation loss: 166.839  ; Best loss: 166.839  ; Accuracy: 0.797367
# 43 Validation loss: 166.75  ; Best loss: 166.75  ; Accuracy: 0.796955
# 44 Validation loss: 166.666  ; Best loss: 166.666  ; Accuracy: 0.797572
# 45 Validation loss: 166.586  ; Best loss: 166.586  ; Accuracy: 0.797161
# 46 Validation loss: 166.511  ; Best loss: 166.511  ; Accuracy: 0.797778
# 47 Validation loss: 166.439  ; Best loss: 166.439  ; Accuracy: 0.797161
# 48 Validation loss: 166.372  ; Best loss: 166.372  ; Accuracy: 0.797984
# 49 Validation loss: 166.309  ; Best loss: 166.309  ; Accuracy: 0.798395
# 50 Validation loss: 166.25  ; Best loss: 166.25  ; Accuracy: 0.797572
# 51 Validation loss: 166.195  ; Best loss: 166.195  ; Accuracy: 0.798395
# 52 Validation loss: 166.145  ; Best loss: 166.145  ; Accuracy: 0.799424
# 53 Validation loss: 166.099  ; Best loss: 166.099  ; Accuracy: 0.798807
# 54 Validation loss: 166.057  ; Best loss: 166.057  ; Accuracy: 0.799424
# 55 Validation loss: 166.02  ; Best loss: 166.02  ; Accuracy: 0.799835
# 56 Validation loss: 165.987  ; Best loss: 165.987  ; Accuracy: 0.79963
# 57 Validation loss: 165.958  ; Best loss: 165.958  ; Accuracy: 0.800658
# 58 Validation loss: 165.933  ; Best loss: 165.933  ; Accuracy: 0.800864
# 59 Validation loss: 165.908  ; Best loss: 165.908  ; Accuracy: 0.801481
# 60 Validation loss: 165.883  ; Best loss: 165.883  ; Accuracy: 0.802098
# 61 Validation loss: 165.855  ; Best loss: 165.855  ; Accuracy: 0.801893
# 62 Validation loss: 165.821  ; Best loss: 165.821  ; Accuracy: 0.80251
# 63 Validation loss: 165.778  ; Best loss: 165.778  ; Accuracy: 0.80395
# 64 Validation loss: 165.727  ; Best loss: 165.727  ; Accuracy: 0.804361
# 65 Validation loss: 165.668  ; Best loss: 165.668  ; Accuracy: 0.804773
# 66 Validation loss: 165.602  ; Best loss: 165.602  ; Accuracy: 0.804361
# 67 Validation loss: 165.532  ; Best loss: 165.532  ; Accuracy: 0.805596
# 68 Validation loss: 165.462  ; Best loss: 165.462  ; Accuracy: 0.805596
# 69 Validation loss: 165.397  ; Best loss: 165.397  ; Accuracy: 0.806418
# 70 Validation loss: 165.338  ; Best loss: 165.338  ; Accuracy: 0.806213
# 71 Validation loss: 165.288  ; Best loss: 165.288  ; Accuracy: 0.807447
# 72 Validation loss: 165.248  ; Best loss: 165.248  ; Accuracy: 0.808681
# 73 Validation loss: 165.217  ; Best loss: 165.217  ; Accuracy: 0.810121
# 74 Validation loss: 165.197  ; Best loss: 165.197  ; Accuracy: 0.811356
# 75 Validation loss: 165.189  ; Best loss: 165.189  ; Accuracy: 0.81259
# 76 Validation loss: 165.192  ; Best loss: 165.189  ; Accuracy: 0.813413
# 77 Validation loss: 165.205  ; Best loss: 165.189  ; Accuracy: 0.813619
# 78 Validation loss: 165.226  ; Best loss: 165.189  ; Accuracy: 0.814236
# 79 Validation loss: 165.252  ; Best loss: 165.189  ; Accuracy: 0.814647
# 80 Validation loss: 165.278  ; Best loss: 165.189  ; Accuracy: 0.815059
# 81 Validation loss: 165.3  ; Best loss: 165.189  ; Accuracy: 0.81691
# 82 Validation loss: 165.312  ; Best loss: 165.189  ; Accuracy: 0.817939
# 83 Validation loss: 165.313  ; Best loss: 165.189  ; Accuracy: 0.818144
# 84 Validation loss: 165.302  ; Best loss: 165.189  ; Accuracy: 0.819173
# 85 Validation loss: 165.279  ; Best loss: 165.189  ; Accuracy: 0.819584
# 86 Validation loss: 165.246  ; Best loss: 165.189  ; Accuracy: 0.820613
# 87 Validation loss: 165.206  ; Best loss: 165.189  ; Accuracy: 0.82123
# 88 Validation loss: 165.159  ; Best loss: 165.159  ; Accuracy: 0.822464
# 89 Validation loss: 165.105  ; Best loss: 165.105  ; Accuracy: 0.822464
# 90 Validation loss: 165.046  ; Best loss: 165.046  ; Accuracy: 0.823287
# 91 Validation loss: 164.981  ; Best loss: 164.981  ; Accuracy: 0.823699
# 92 Validation loss: 164.909  ; Best loss: 164.909  ; Accuracy: 0.824522
# 93 Validation loss: 164.831  ; Best loss: 164.831  ; Accuracy: 0.824933
# 94 Validation loss: 164.747  ; Best loss: 164.747  ; Accuracy: 0.824933
# 95 Validation loss: 164.658  ; Best loss: 164.658  ; Accuracy: 0.824933
# 96 Validation loss: 164.564  ; Best loss: 164.564  ; Accuracy: 0.825139
# 97 Validation loss: 164.466  ; Best loss: 164.466  ; Accuracy: 0.825756
# 98 Validation loss: 164.366  ; Best loss: 164.366  ; Accuracy: 0.826579
# 99 Validation loss: 164.267  ; Best loss: 164.267  ; Accuracy: 0.827196
# 100 Validation loss: 164.169  ; Best loss: 164.169  ; Accuracy: 0.82843
# 101 Validation loss: 164.077  ; Best loss: 164.077  ; Accuracy: 0.829459
# 102 Validation loss: 163.994  ; Best loss: 163.994  ; Accuracy: 0.829665
# 103 Validation loss: 163.923  ; Best loss: 163.923  ; Accuracy: 0.829665
# 104 Validation loss: 163.865  ; Best loss: 163.865  ; Accuracy: 0.830899
# 105 Validation loss: 163.818  ; Best loss: 163.818  ; Accuracy: 0.830488
# 106 Validation loss: 163.78  ; Best loss: 163.78  ; Accuracy: 0.831516
# 107 Validation loss: 163.748  ; Best loss: 163.748  ; Accuracy: 0.831516
# 108 Validation loss: 163.724  ; Best loss: 163.724  ; Accuracy: 0.831928
# 109 Validation loss: 163.708  ; Best loss: 163.708  ; Accuracy: 0.832956
# 110 Validation loss: 163.705  ; Best loss: 163.705  ; Accuracy: 0.832545
# 111 Validation loss: 163.717  ; Best loss: 163.705  ; Accuracy: 0.832339
# 112 Validation loss: 163.743  ; Best loss: 163.705  ; Accuracy: 0.832339
# 113 Validation loss: 163.78  ; Best loss: 163.705  ; Accuracy: 0.832545
# 114 Validation loss: 163.827  ; Best loss: 163.705  ; Accuracy: 0.833162
# 115 Validation loss: 163.883  ; Best loss: 163.705  ; Accuracy: 0.832545
# 116 Validation loss: 163.947  ; Best loss: 163.705  ; Accuracy: 0.831722
# 117 Validation loss: 164.021  ; Best loss: 163.705  ; Accuracy: 0.83131
# 118 Validation loss: 164.107  ; Best loss: 163.705  ; Accuracy: 0.83131
# 119 Validation loss: 164.204  ; Best loss: 163.705  ; Accuracy: 0.83131
# 120 Validation loss: 164.3  ; Best loss: 163.705  ; Accuracy: 0.83131
# 121 Validation loss: 164.363  ; Best loss: 163.705  ; Accuracy: 0.831722
# 122 Validation loss: 164.382  ; Best loss: 163.705  ; Accuracy: 0.831722
# 123 Validation loss: 164.385  ; Best loss: 163.705  ; Accuracy: 0.831516
# 124 Validation loss: 164.392  ; Best loss: 163.705  ; Accuracy: 0.830899
# 125 Validation loss: 164.409  ; Best loss: 163.705  ; Accuracy: 0.830899
# 126 Validation loss: 164.439  ; Best loss: 163.705  ; Accuracy: 0.831516
# 127 Validation loss: 164.487  ; Best loss: 163.705  ; Accuracy: 0.831722
# 128 Validation loss: 164.554  ; Best loss: 163.705  ; Accuracy: 0.831722
# 129 Validation loss: 164.633  ; Best loss: 163.705  ; Accuracy: 0.830899
# 130 Validation loss: 164.698  ; Best loss: 163.705  ; Accuracy: 0.830487
# Early stop in epoch 130
# Training Finish!!!
